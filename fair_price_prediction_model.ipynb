# %%
import pandas as pd

#Load data from csvs
listings_nc = "http://data.insideairbnb.com/united-states/nc/asheville/2022-12-21/data/listings.csv.gz"
listings_nc_df = pd.read_csv(listings_nc)

listings_tx = "http://data.insideairbnb.com/united-states/tx/austin/2022-12-15/data/listings.csv.gz"
listings_tx_df = pd.read_csv(listings_tx)

listings_ma = "http://data.insideairbnb.com/united-states/ma/boston/2022-12-21/data/listings.csv.gz"
listings_ma_df = pd.read_csv(listings_ma)

listings_fl = "http://data.insideairbnb.com/united-states/fl/broward-county/2022-12-28/data/listings.csv.gz"
listings_fl_df = pd.read_csv(listings_fl)

listings_nv = "http://data.insideairbnb.com/united-states/nv/clark-county-nv/2022-12-21/data/listings.csv.gz"
listings_nv_df = pd.read_csv(listings_nv)

#We will combine the datasets now
listings_df = pd.concat([listings_nc_df, listings_tx_df, listings_ma_df, listings_fl_df, listings_nv_df])
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52266 entries, 0 to 15183
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            52266 non-null  int64
#  1   listing_url                                   52266 non-null  object
#  2   scrape_id                                     52266 non-null  int64
#  3   last_scraped                                  52266 non-null  object
#  4   source                                        52266 non-null  object
#  5   name                                          52265 non-null  object
#  6   description                                   51576 non-null  object
#  7   neighborhood_overview                         31641 non-null  object
#  8   picture_url                                   52265 non-null  object
#  9   host_id                                       52266 non-null  int64
#  10  host_url                                      52266 non-null  object
#  11  host_name                                     52262 non-null  object
#  12  host_since                                    52262 non-null  object
#  13  host_location                                 41049 non-null  object
#  14  host_about                                    30319 non-null  object
#  15  host_response_time                            44612 non-null  object
#  16  host_response_rate                            44612 non-null  object
#  17  host_acceptance_rate                          46747 non-null  object
#  18  host_is_superhost                             52195 non-null  object
#  19  host_thumbnail_url                            52262 non-null  object
#  20  host_picture_url                              52262 non-null  object
#  21  host_neighbourhood                            34736 non-null  object
#  22  host_listings_count                           52262 non-null  float64
#  23  host_total_listings_count                     52262 non-null  float64
#  24  host_verifications                            52266 non-null  object
#  25  host_has_profile_pic                          52262 non-null  object
#  26  host_identity_verified                        52262 non-null  object
#  27  neighbourhood                                 31642 non-null  object
#  28  neighbourhood_cleansed                        52266 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      52266 non-null  float64
#  31  longitude                                     52266 non-null  float64
#  32  property_type                                 52266 non-null  object
#  33  room_type                                     52266 non-null  object
#  34  accommodates                                  52266 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                52012 non-null  object
#  37  bedrooms                                      48349 non-null  float64
#  38  beds                                          51717 non-null  float64
#  39  amenities                                     52266 non-null  object
#  40  price                                         52266 non-null  object
#  41  minimum_nights                                52266 non-null  int64
#  42  maximum_nights                                52266 non-null  int64
#  43  minimum_minimum_nights                        52263 non-null  float64
#  44  maximum_minimum_nights                        52263 non-null  float64
#  45  minimum_maximum_nights                        52263 non-null  float64
#  46  maximum_maximum_nights                        52263 non-null  float64
#  47  minimum_nights_avg_ntm                        52263 non-null  float64
#  48  maximum_nights_avg_ntm                        52263 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              52266 non-null  object
#  51  availability_30                               52266 non-null  int64
#  52  availability_60                               52266 non-null  int64
#  53  availability_90                               52266 non-null  int64
#  54  availability_365                              52266 non-null  int64
#  55  calendar_last_scraped                         52266 non-null  object
#  56  number_of_reviews                             52266 non-null  int64
#  57  number_of_reviews_ltm                         52266 non-null  int64
#  58  number_of_reviews_l30d                        52266 non-null  int64
#  59  first_review                                  40962 non-null  object
#  60  last_review                                   40962 non-null  object
#  61  review_scores_rating                          40962 non-null  float64
#  62  review_scores_accuracy                        40819 non-null  float64
#  63  review_scores_cleanliness                     40820 non-null  float64
#  64  review_scores_checkin                         40815 non-null  float64
#  65  review_scores_communication                   40820 non-null  float64
#  66  review_scores_location                        40814 non-null  float64
#  67  review_scores_value                           40814 non-null  float64
#  68  license                                       2607 non-null   object
#  69  instant_bookable                              52266 non-null  object
#  70  calculated_host_listings_count                52266 non-null  int64
#  71  calculated_host_listings_count_entire_homes   52266 non-null  int64
#  72  calculated_host_listings_count_private_rooms  52266 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   52266 non-null  int64
#  74  reviews_per_month                             40962 non-null  float64
# dtypes: float64(23), int64(17), object(35)
# memory usage: 30.3+ MB

# %%
#Lets clean up some of the numeric and ordinal values
listings_df.head(3)

#We can remove some of these colums that dont add anything
#These include id, listing_url, scrape_id, last_scraped, source, Name, description, neighborhood_overview, picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_thumbnail_url,
# host_picture_url, host_neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, calendar_last_scraped
listings_df = listings_df.drop(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 
                 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 
                 'host_neighbourhood', 'neighbourhood', 'bathrooms', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'calendar_last_scraped', 'license', 'first_review', 'last_review',
                 'calendar_updated', 'property_type', 'host_verifications', 'room_type'],  axis=1)

#now lets change some of the object datatypes to float/int, ordinal or categorical
listings_df['host_acceptance_rate'] = listings_df['host_acceptance_rate'].str.rstrip('%').astype('float') / 100.0
listings_df['host_response_rate'] = listings_df['host_response_rate'].str.rstrip('%').astype('float') / 100.0
listings_df['price'] = listings_df['price'].str.replace(',', '').str.lstrip('$').astype('float')

listings_df["longitude"] = listings_df["longitude"].map(lambda x: x + 180)
listings_df["latitude"] = listings_df["latitude"].map(lambda x: x + 90)

# listings_df["room_type"] = pd.Categorical(list(listings_df['room_type'].astype('str')))
listings_df["amenities"] = listings_df["amenities"].map(lambda x: len(x))

def string_to_binary(bool_string):
    if str(bool_string) == 'f':
      return 0
    elif str(bool_string) == 't':
      return 1
    else:
      return None

listings_df['host_is_superhost'] = listings_df['host_is_superhost'].apply(string_to_binary)
listings_df['host_has_profile_pic'] = listings_df['host_has_profile_pic'].apply(string_to_binary)
listings_df['host_identity_verified'] = listings_df['host_identity_verified'].apply(string_to_binary)
listings_df['has_availability'] = listings_df['has_availability'].apply(string_to_binary)
listings_df['instant_bookable'] = listings_df['instant_bookable'].apply(string_to_binary)

listings_df['bathrooms'] = listings_df['bathrooms_text'].str.extract('(\d+)', expand=False).astype('float')
listings_df = listings_df.drop(['bathrooms_text'], axis=1)

listings_df['host_response_time'] = listings_df['host_response_time'].map(lambda x: {'a few days or more': 0, 'within a day': 1, 'within a few hours': 2, 'within an hour': 3}.get(x, 0))

listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52266 entries, 0 to 15183
# Data columns (total 45 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_response_time                            52266 non-null  int64
#  1   host_response_rate                            44612 non-null  float64
#  2   host_acceptance_rate                          46747 non-null  float64
#  3   host_is_superhost                             52195 non-null  float64
#  4   host_listings_count                           52262 non-null  float64
#  5   host_total_listings_count                     52262 non-null  float64
#  6   host_has_profile_pic                          52262 non-null  float64
#  7   host_identity_verified                        52262 non-null  float64
#  8   latitude                                      52266 non-null  float64
#  9   longitude                                     52266 non-null  float64
#  10  accommodates                                  52266 non-null  int64
#  11  bedrooms                                      48349 non-null  float64
#  12  beds                                          51717 non-null  float64
#  13  amenities                                     52266 non-null  int64
#  14  price                                         52266 non-null  float64
#  15  minimum_nights                                52266 non-null  int64
#  16  maximum_nights                                52266 non-null  int64
#  17  minimum_minimum_nights                        52263 non-null  float64
#  18  maximum_minimum_nights                        52263 non-null  float64
#  19  minimum_maximum_nights                        52263 non-null  float64
#  20  maximum_maximum_nights                        52263 non-null  float64
#  21  minimum_nights_avg_ntm                        52263 non-null  float64
#  22  maximum_nights_avg_ntm                        52263 non-null  float64
#  23  has_availability                              52266 non-null  int64
#  24  availability_30                               52266 non-null  int64
#  25  availability_60                               52266 non-null  int64
#  26  availability_90                               52266 non-null  int64
#  27  availability_365                              52266 non-null  int64
#  28  number_of_reviews                             52266 non-null  int64
#  29  number_of_reviews_ltm                         52266 non-null  int64
#  30  number_of_reviews_l30d                        52266 non-null  int64
#  31  review_scores_rating                          40962 non-null  float64
#  32  review_scores_accuracy                        40819 non-null  float64
#  33  review_scores_cleanliness                     40820 non-null  float64
#  34  review_scores_checkin                         40815 non-null  float64
#  35  review_scores_communication                   40820 non-null  float64
#  36  review_scores_location                        40814 non-null  float64
#  37  review_scores_value                           40814 non-null  float64
#  38  instant_bookable                              52266 non-null  int64
#  39  calculated_host_listings_count                52266 non-null  int64
#  40  calculated_host_listings_count_entire_homes   52266 non-null  int64
#  41  calculated_host_listings_count_private_rooms  52266 non-null  int64
#  42  calculated_host_listings_count_shared_rooms   52266 non-null  int64
#  43  reviews_per_month                             40962 non-null  float64
#  44  bathrooms                                     51976 non-null  float64
# dtypes: float64(27), int64(18)
# memory usage: 18.3 MB

# %%
import missingno as msno
#Next we will start looking at the data

#Lets look at our missing/null values
print(f'Missing values count: {listings_df.isnull().values.sum()}')

msno.bar(listings_df)
msno.matrix(listings_df)
# Out:
# Missing values count: 109336
# <AxesSubplot:>

# %%
#Next lets look at the datas scewdness
import plotly.express as px
from scipy.stats import skew, norm
from scipy import stats
import matplotlib.pyplot as plt
fig = px.box(listings_df, y = 'price')
fig.show()

fig = px.histogram(listings_df, x = 'price')
fig.show()
# Out:
# <div>                            <div id="b816caa7-95a5-43ea-aada-bd84d0b0faee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b816caa7-95a5-43ea-aada-bd84d0b0faee")) {                    Plotly.newPlot(                        "b816caa7-95a5-43ea-aada-bd84d0b0faee",                        [{"alignmentgroup":"True","hovertemplate":"price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[100.0,100.0,66.0,29.0,45.0,134.0,68.0,83.0,289.0,65.0,159.0,136.0,159.0,164.0,174.0,167.0,67.0,54.0,73.0,249.0,95.0,100.0,264.0,198.0,57.0,95.0,126.0,79.0,279.0,151.0,130.0,105.0,193.0,80.0,95.0,156.0,65.0,95.0,56.0,100.0,159.0,80.0,158.0,85.0,199.0,85.0,199.0,79.0,90.0,85.0,320.0,177.0
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/1396127031.py:10: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
# deal with the skewness issue
import numpy as np
listings_df['price_log'] = np.log(1 + listings_df['price'])
# normality_plot(listings_df['price_log'])

# List of skewed columns
skewed_cols = list(skewness[abs(skewness) > 1].index)


# Remove 'MSSubClass' and 'SalePrice'
skewed_cols = [
    col for col in skewed_cols if col not in ['price','price_log']
]

# Log-transform skewed columns
for col in skewed_cols:
    listings_df[col] = np.log(1 + listings_df[col])
  
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51345 entries, 0 to 15183
# Data columns (total 46 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_response_time                            51345 non-null  float64
#  1   host_response_rate                            43827 non-null  float64
#  2   host_acceptance_rate                          45917 non-null  float64
#  3   host_is_superhost                             51294 non-null  float64
#  4   host_listings_count                           51341 non-null  float64
#  5   host_total_listings_count                     51341 non-null  float64
#  6   host_has_profile_pic                          51341 non-null  float64
#  7   host_identity_verified                        51341 non-null  float64
#  8   latitude                                      51345 non-null  float64
#  9   longitude                                     51345 non-null  float64
#  10  accommodates                                  51345 non-null  float64
#  11  bedrooms                                      47465 non-null  float64
#  12  beds                                          50807 non-null  float64
#  13  amenities                                     51345 non-null  int64
#  14  price                                         51345 non-null  float64
#  15  minimum_nights                                51345 non-null  float64
#  16  maximum_nights                                51345 non-null  int64
#  17  minimum_minimum_nights                        51343 non-null  float64
#  18  maximum_minimum_nights                        51343 non-null  float64
#  19  minimum_maximum_nights                        51343 non-null  float64
#  20  maximum_maximum_nights                        51343 non-null  float64
#  21  minimum_nights_avg_ntm                        51343 non-null  float64
#  22  maximum_nights_avg_ntm                        51343 non-null  float64
#  23  has_availability                              51345 non-null  float64
#  24  availability_30                               51345 non-null  int64
#  25  availability_60                               51345 non-null  int64
#  26  availability_90                               51345 non-null  int64
#  27  availability_365                              51345 non-null  int64
#  28  number_of_reviews                             51345 non-null  float64
#  29  number_of_reviews_ltm                         51345 non-null  float64
#  30  number_of_reviews_l30d                        51345 non-null  float64
#  31  review_scores_rating                          40389 non-null  float64
#  32  review_scores_accuracy                        40250 non-null  float64
#  33  review_scores_cleanliness                     40251 non-null  float64
#  34  review_scores_checkin                         40246 non-null  float64
#  35  review_scores_communication                   40251 non-null  float64
#  36  review_scores_location                        40245 non-null  float64
#  37  review_scores_value                           40245 non-null  float64
#  38  instant_bookable                              51345 non-null  int64
#  39  calculated_host_listings_count                51345 non-null  float64
#  40  calculated_host_listings_count_entire_homes   51345 non-null  float64
#  41  calculated_host_listings_count_private_rooms  51345 non-null  float64
#  42  calculated_host_listings_count_shared_rooms   51345 non-null  float64
#  43  reviews_per_month                             40389 non-null  float64
#  44  bathrooms                                     51069 non-null  float64
#  45  price_log                                     51345 non-null  float64
# dtypes: float64(39), int64(7)
# memory usage: 18.4 MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(20, 10))
corr = listings_df.corr()[['price']]
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(30, 10))
cor_df = listings_df.corr(method = "pearson").round(2)
sns.heatmap(cor_df, ax=ax, annot=True)

annot_labels = np.empty_like(cor_df, dtype=str)
annot_mask = cor_df >= 0.8
annot_labels[annot_mask] = 'T' 
fig, ax = plt.subplots(figsize=(30, 10))
sns.heatmap(cor_df, annot=annot_labels, fmt='')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
listings_df["price"] = listings_df["price"].replace(0, np.NaN)

listings_df = listings_df.fillna(listings_df.mean())
# listings_df = listings_df.dropna()

# Separating X and y
X = listings_df.drop('price', axis=1)
Y = listings_df.price

# %%
# Log Transform
def log_transfer(X_train, X_test):
    skewness = X_train.skew().sort_values(ascending=False)
    skewed_cols = list(skewness[abs(skewness) > 1].index)
    
    # Log-transform skewed columns
    for col in skewed_cols:
        X_train[col] = np.log(1 + X_train[col])
        X_test[col] = np.log(1 + X_test[col])

# Scaling
def feature_scaling(X_train, X_test):
    scaler = StandardScaler()
    numerical_cols = list(X_train.select_dtypes(exclude=['object', 'category']).columns)
    scaler.fit(X_train[numerical_cols])
    X_train[numerical_cols] = scaler.transform(X_train[numerical_cols])   
    X_test[numerical_cols] = scaler.transform(X_test[numerical_cols])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=123)

log_transfer(X_train, X_test)
feature_scaling(X_train, X_test)
# Out:
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2265463720.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2265463720.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2265463720.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\python\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2265463720.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\python\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Building the model
from IPython.display import SVG

from keras import models, layers, optimizers, regularizers
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import model_to_dot

nn = models.Sequential()
nn.add(layers.Dense(32, input_shape=(X_train.shape[1],), activation='relu'))
# nn.add(layers.Dropout(0.1))
nn.add(layers.Dense(16, activation='relu'))
# nn.add(layers.Dropout(0.1))
nn.add(layers.Dense(8, activation='relu'))
# nn.add(layers.Dropout(0.1))
nn.add(layers.Dense(4, activation='relu'))
# nn.add(layers.Dropout(0.1))
nn.add(layers.Dense(1, activation='linear'))

early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=50, restore_best_weights=True)

# Compiling the model
nn.compile(loss='mean_squared_error',
    optimizer=optimizers.Adam(learning_rate=0.003),
    metrics=['mean_squared_error']) 

# Model summary
nn.summary()

# Visualising the neural network
# SVG(model_to_dot(nn2, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_50 (Dense)            (None, 32)                1472
#
#  dense_51 (Dense)            (None, 16)                528
#
#  dense_52 (Dense)            (None, 8)                 136
#
#  dense_53 (Dense)            (None, 4)                 36
#
#  dense_54 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 2,177
# Trainable params: 2,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model

history = nn.fit(X_train, Y_train, epochs=1000, batch_size=512, validation_split = 0.1, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 64/64 [==============================] - 1s 7ms/step - loss: 149966.6875 - mean_squared_error: 149966.6875 - val_loss: 73862.7109 - val_mean_squared_error: 73862.7109
# Epoch 2/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 57525.1172 - mean_squared_error: 57525.1172 - val_loss: 49796.6328 - val_mean_squared_error: 49796.6328
# Epoch 3/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 40612.2188 - mean_squared_error: 40612.2188 - val_loss: 33313.5625 - val_mean_squared_error: 33313.5625
# Epoch 4/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 24146.1641 - mean_squared_error: 24146.1641 - val_loss: 18512.3301 - val_mean_squared_error: 18512.3301
# Epoch 5/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 13942.7451 - mean_squared_error: 13942.7451 - val_loss: 12232.6074 - val_mean_squared_error: 12232.6074
# Epoch 6/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 9777.4609 - mean_squared_error: 9777.4609 - val_loss: 8974.2871 - val_mean_squared_error: 8974.2871
# Epoch 7/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 7309.1460 - mean_squared_error: 7309.1460 - val_loss: 6915.2910 - val_mean_squared_error: 6915.2910
# Epoch 8/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 5512.7363 - mean_squared_error: 5512.7363 - val_loss: 5256.3950 - val_mean_squared_error: 5256.3950
# Epoch 9/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 4271.1821 - mean_squared_error: 4271.1821 - val_loss: 4270.0913 - val_mean_squared_error: 4270.0913
# Epoch 10/1000
# 64/64 [==============================] - 0s 5ms/step - loss:
1000
# 64/64 [==============================] - 0s 5ms/step - loss: 50.2932 - mean_squared_error: 50.2932 - val_loss: 81.0625 - val_mean_squared_error: 81.0625
# Epoch 90/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 47.7604 - mean_squared_error: 47.7604 - val_loss: 83.9776 - val_mean_squared_error: 83.9776
# Epoch 91/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 48.7074 - mean_squared_error: 48.7074 - val_loss: 84.9875 - val_mean_squared_error: 84.9875
# Epoch 92/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 34.6832 - mean_squared_error: 34.6832 - val_loss: 69.1490 - val_mean_squared_error: 69.1490
# Epoch 93/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 47.2424 - mean_squared_error: 47.2424 - val_loss: 144.7906 - val_mean_squared_error: 144.7906
# Epoch 94/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 92.6179 - mean_squared_error: 92.6179 - val_loss: 63.7402 - val_mean_squared_error: 63.7402
# Epoch 95/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 52.0267 - mean_squared_error: 52.0267 - val_loss: 130.2516 - val_mean_squared_error: 130.2516
# Epoch 96/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 90.8198 - mean_squared_error: 90.8198 - val_loss: 94.9084 - val_mean_squared_error: 94.9084
# Epoch 97/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 51.5967 - mean_squared_error: 51.5967 - val_loss: 95.2524 - val_mean_squared_error: 95.2524
# Epoch 98/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 124.0452 - mean_squared_error: 124.0452 - val_loss: 319.5714 - val_mean_squared_error: 319.5714
# Epoch 99/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 393.3651 - mean_squared_error: 393.3651 - val_loss: 290.1196 - val_mean_squared_error: 290.1196
# Epoch 100/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 115.7483 - mean_squared_error: 115.7483 - val_loss: 98.7863 - val_mean_squared_error: 98.7863
# Epoch 101/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 63.4792 - mean_squared_error: 63.4792 - val_loss: 125.6627 - val_mean_squared_error: 125.6627
# Epoch 102/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 124.8630 - mean_squared_error: 124.8630 - val_loss: 119.5771 - val_mean_squared_error: 119.5771
# Epoch 103/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 57.4746 - mean_squared_error: 57.4746 - val_loss: 85.2833 - val_mean_squared_error: 85.2833
# Epoch 104/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 76.0601 - mean_squared_error: 76.0601 - val_loss: 132.4003 - val_mean_squared_error: 132.4003
# Epoch 105/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 48.1750 - mean_squared_error: 48.1750 - val_loss: 87.1791 - val_mean_squared_error: 87.1791
# Epoch 106/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 43.2925 - mean_squared_error: 43.2925 - val_loss: 87.6526 - val_mean_squared_error: 87.6526
# Epoch 107/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 56.3532 - mean_squared_error: 56.3532 - val_loss: 64.8248 - val_mean_squared_error: 64.8248
# Epoch 108/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 36.0131 - mean_squared_error: 36.0131 - val_loss: 93.0791 - val_mean_squared_error: 93.0791
# Epoch 109/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 99.9090 - mean_squared_error: 99.9090 - val_loss: 211.6240 - val_mean_squared_error: 211.6240
# Epoch 110/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 80.8574 - mean_squared_error: 80.8574 - val_loss: 105.8881 - val_mean_squared_error: 105.8881
# Epoch 111/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 41.7390 - mean_squared_error: 41.7390 - val_loss: 70.7962 - val_mean_squared_error: 70.7962
# Epoch 112/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 35.8001 - mean_squared_error: 35.8001 - val_loss: 73.0024 - val_mean_squared_error: 73.0024
# Epoch 113/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 55.1937 - mean_squared_error: 55.1937 - val_loss: 92.3938 - val_mean_squared_error: 92.3938
# Epoch 114/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 79.5526 - mean_squared_error: 79.5526 - val_loss: 58.8162 - val_mean_squared_error: 58.8162
# Epoch 115/1000
# 64/64 [==============================] - 0s 6ms/step - loss:
1000
# 64/64 [==============================] - 0s 5ms/step - loss: 53.9846 - mean_squared_error: 53.9846 - val_loss: 73.6205 - val_mean_squared_error: 73.6205
# Epoch 143/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 41.2474 - mean_squared_error: 41.2474 - val_loss: 54.5616 - val_mean_squared_error: 54.5616
# Epoch 144/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 33.2221 - mean_squared_error: 33.2221 - val_loss: 60.6833 - val_mean_squared_error: 60.6833
# Epoch 145/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 24.7855 - mean_squared_error: 24.7855 - val_loss: 78.7599 - val_mean_squared_error: 78.7599
# Epoch 146/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 49.7238 - mean_squared_error: 49.7238 - val_loss: 72.0340 - val_mean_squared_error: 72.0340
# Epoch 147/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 43.7263 - mean_squared_error: 43.7263 - val_loss: 86.7272 - val_mean_squared_error: 86.7272
# Epoch 148/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 38.3076 - mean_squared_error: 38.3076 - val_loss: 60.8383 - val_mean_squared_error: 60.8383
# Epoch 149/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 30.3458 - mean_squared_error: 30.3458 - val_loss: 63.8334 - val_mean_squared_error: 63.8334
# Epoch 150/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 95.8518 - mean_squared_error: 95.8518 - val_loss: 78.9853 - val_mean_squared_error: 78.9853
# Epoch 151/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 42.3828 - mean_squared_error: 42.3828 - val_loss: 71.0979 - val_mean_squared_error: 71.0979
# Epoch 152/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 46.1788 - mean_squared_error: 46.1788 - val_loss: 90.3459 - val_mean_squared_error: 90.3459
# Epoch 153/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 80.5310 - mean_squared_error: 80.5310 - val_loss: 71.0518 - val_mean_squared_error: 71.0518
# Epoch 154/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 45.4309 - mean_squared_error: 45.4309 - val_loss: 64.0739 - val_mean_squared_error: 64.0739
# Epoch 155/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 75.6159 - mean_squared_error: 75.6159 - val_loss: 85.6260 - val_mean_squared_error: 85.6260
# Epoch 156/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 67.7004 - mean_squared_error: 67.7004 - val_loss: 93.1211 - val_mean_squared_error: 93.1211
# Epoch 157/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 54.3984 - mean_squared_error: 54.3984 - val_loss: 255.0066 - val_mean_squared_error: 255.0066
# Epoch 158/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 234.0320 - mean_squared_error: 234.0320 - val_loss: 169.0645 - val_mean_squared_error: 169.0645
# Epoch 159/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 61.9781 - mean_squared_error: 61.9781 - val_loss: 98.3768 - val_mean_squared_error: 98.3768
# Epoch 160/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 47.0673 - mean_squared_error: 47.0673 - val_loss: 70.2524 - val_mean_squared_error: 70.2524
# Epoch 161/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 70.1686 - mean_squared_error: 70.1686 - val_loss: 179.7478 - val_mean_squared_error: 179.7478
# Epoch 162/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 74.0189 - mean_squared_error: 74.0189 - val_loss: 100.8827 - val_mean_squared_error: 100.8827
# Epoch 163/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 63.6685 - mean_squared_error: 63.6685 - val_loss: 79.3550 - val_mean_squared_error: 79.3550
# Epoch 164/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 57.9455 - mean_squared_error: 57.9455 - val_loss: 95.0407 - val_mean_squared_error: 95.0407
# Epoch 165/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 97.7169 - mean_squared_error: 97.7169 - val_loss: 101.5639 - val_mean_squared_error: 101.5639
# Epoch 166/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 48.8359 - mean_squared_error: 48.8359 - val_loss: 76.7534 - val_mean_squared_error: 76.7534
# Epoch 167/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 67.2283 - mean_squared_error: 67.2283 - val_loss: 122.1942 - val_mean_squared_error: 122.1942
# Epoch 168/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 41.2533 - mean_squared_error: 41.2533 - val_loss: 68.7820 - val_mean_squared_error: 68.7820
# Epoch 169/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 44.6044 - mean_squared_error: 44.6044 - val_loss: 79.2594 - val_mean_squared_error: 79.2594
# Epoch 170/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 47.9514 - mean_squared_error: 47.9514 - val_loss: 63.0222 - val_mean_squared_error: 63.0222
# Epoch 171/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 218.8633 - mean_squared_error: 218.8633 - val_loss: 205.6187 - val_mean_squared_error: 205.6187
# Epoch 172/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 139.1362 - mean_squared_error: 139.1362 - val_loss: 220.0450 - val_mean_squared_error: 220.0450
# Epoch 173/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 117.5534 - mean_squared_error: 117.5534 - val_loss: 84.1460 - val_mean_squared_error: 84.1460
# Epoch 174/1000
# 64/64 [==============================] - 0s 6ms/step - loss: 55.1541 - mean_squared_error: 55.1541 - val_loss: 53.4080 - val_mean_squared_error: 53.4080
# Epoch 175/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 32.2543 - mean_squared_error: 32.2543 - val_loss: 72.3299 - val_mean_squared_error: 72.3299
# Epoch 176/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 37.3281 - mean_squared_error: 37.3281 - val_loss: 77.7079 - val_mean_squared_error: 77.7079
# Epoch 177/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 81.2385 - mean_squared_error: 81.2385 - val_loss: 91.3636 - val_mean_squared_error: 91.3636
# Epoch 178/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 44.5110 - mean_squared_error: 44.5110 - val_loss: 65.1240 - val_mean_squared_error: 65.1240
# Epoch 179/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 66.7070 - mean_squared_error: 66.7070 - val_loss: 125.4579 - val_mean_squared_error: 125.4579
# Epoch 180/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 46.6556 - mean_squared_error: 46.6556 - val_loss: 161.7375 - val_mean_squared_error: 161.7375
# Epoch 181/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 60.3714 - mean_squared_error: 60.3714 - val_loss: 55.1036 - val_mean_squared_error: 55.1036
# Epoch 182/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 28.3051 - mean_squared_error: 28.3051 - val_loss: 45.3041 - val_mean_squared_error: 45.3041
# Epoch 183/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 27.3330 - mean_squared_error: 27.3330 - val_loss: 64.9224 - val_mean_squared_error: 64.9224
# Epoch 184/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 27.4972 - mean_squared_error: 27.4972 - val_loss: 42.7329 - val_mean_squared_error: 42.7329
# Epoch 185/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 27.3111 - mean_squared_error: 27.3111 - val_loss: 35.9952 - val_mean_squared_error: 35.9952
# Epoch 186/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 24.2039 - mean_squared_error: 24.2039 - val_loss: 82.5502 - val_mean_squared_error: 82.5502
# Epoch 187/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 183.2480 - mean_squared_error: 183.2480 - val_loss: 90.7992 - val_mean_squared_error: 90.7992
# Epoch 188/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 105.7536 - mean_squared_error: 105.7536 - val_loss: 92.2868 - val_mean_squared_error: 92.2868
# Epoch 189/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 88.0034 - mean_squared_error: 88.0034 - val_loss: 75.8439 - val_mean_squared_error: 75.8439
# Epoch 190/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 35.8159 - mean_squared_error: 35.8159 - val_loss: 83.5335 - val_mean_squared_error: 83.5335
# Epoch 191/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 146.0676 - mean_squared_error: 146.0676 - val_loss: 75.8387 - val_mean_squared_error: 75.8387
# Epoch 192/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 33.6035 - mean_squared_error: 33.6035 - val_loss: 46.4652 - val_mean_squared_error: 46.4652
# Epoch 193/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 21.7819 - mean_squared_error: 21.7819 - val_loss: 52.8751 - val_mean_squared_error: 52.8751
# Epoch 194/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 36.1099 - mean_squared_error: 36.1099 - val_loss: 59.2371 - val_mean_squared_error: 59.2371
# Epoch 195/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 29.5763 - mean_squared_error: 29.5763 - val_loss: 45.6983 - val_mean_squared_error: 45.6983
# Epoch 196/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 27.6641 - mean_squared_error: 27.6641 - val_loss: 36.5514 - val_mean_squared_error: 36.5514
# Epoch 197/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 36.3138 - mean_squared_error: 36.3138 - val_loss: 49.9265 - val_mean_squared_error: 49.9265
# Epoch 198/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 33.0521 - mean_squared_error: 33.0521 - val_loss: 85.7427 - val_mean_squared_error: 85.7427
# Epoch 199/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 60.6567 - mean_squared_error: 60.6567 - val_loss: 136.5725 - val_mean_squared_error: 136.5725
# Epoch 200/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 239.3393 - mean_squared_error: 239.3393 - val_loss: 136.0926 - val_mean_squared_error: 136.0926
# Epoch 201/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 38.9794 - mean_squared_error: 38.9794 - val_loss: 40.6405 - val_mean_squared_error: 40.6405
# Epoch 202/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 69.1922 - mean_squared_error: 69.1922 - val_loss: 74.2813 - val_mean_squared_error: 74.2813
# Epoch 203/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 68.1789 - mean_squared_error: 68.1789 - val_loss: 75.9145 - val_mean_squared_error: 75.9145
# Epoch 204/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 67.3129 - mean_squared_error: 67.3129 - val_loss: 48.4762 - val_mean_squared_error: 48.4762
# Epoch 205/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 60.8903 - mean_squared_error: 60.8903 - val_loss: 83.1352 - val_mean_squared_error: 83.1352
# Epoch 206/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 71.0666 - mean_squared_error: 71.0666 - val_loss: 55.6425 - val_mean_squared_error: 55.6425
# Epoch 207/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 46.9129 - mean_squared_error: 46.9129 - val_loss: 82.5358 - val_mean_squared_error: 82.5358
# Epoch 208/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 32.6774 - mean_squared_error: 32.6774 - val_loss: 49.5536 - val_mean_squared_error: 49.5536
# Epoch 209/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 26.5368 - mean_squared_error: 26.5368 - val_loss: 80.5796 - val_mean_squared_error: 80.5796
# Epoch 210/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 28.6916 - mean_squared_error: 28.6916 - val_loss: 45.6526 - val_mean_squared_error: 45.6526
# Epoch 211/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 20.2001 - mean_squared_error: 20.2001 - val_loss: 52.1467 - val_mean_squared_error: 52.1467
# Epoch 212/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 50.5187 - mean_squared_error: 50.5187 - val_loss: 87.5699 - val_mean_squared_error: 87.5699
# Epoch 213/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 69.6895 - mean_squared_error: 69.6895 - val_loss: 82.2111 - val_mean_squared_error: 82.2111
# Epoch 214/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 139.7866 - mean_squared_error: 139.7866 - val_loss: 95.1567 - val_mean_squared_error: 95.1567
# Epoch 215/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 65.8428 - mean_squared_error: 65.8428 - val_loss: 100.6482 - val_mean_squared_error: 100.6482
# Epoch 216/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 84.1891 - mean_squared_error: 84.1891 - val_loss: 44.4596 - val_mean_squared_error: 44.4596
# Epoch 217/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 64.8453 - mean_squared_error: 64.8453 - val_loss: 76.1423 - val_mean_squared_error: 76.1423
# Epoch 218/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 40.4686 - mean_squared_error: 40.4686 - val_loss: 70.8598 - val_mean_squared_error: 70.8598
# Epoch 219/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 107.4140 - mean_squared_error: 107.4140 - val_loss: 277.5450 - val_mean_squared_error: 277.5450
# Epoch 220/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 85.2553 - mean_squared_error: 85.2553 - val_loss: 61.2765 - val_mean_squared_error: 61.2765
# Epoch 221/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 27.1599 - mean_squared_error: 27.1599 - val_loss: 47.8938 - val_mean_squared_error: 47.8938
# Epoch 222/1000
# 64/64 [==============================] - 0s 5ms/step - loss:
1000
# 64/64 [==============================] - 0s 5ms/step - loss: 22.6036 - mean_squared_error: 22.6036 - val_loss: 68.7182 - val_mean_squared_error: 68.7182
# Epoch 275/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 23.4827 - mean_squared_error: 23.4827 - val_loss: 44.8099 - val_mean_squared_error: 44.8099
# Epoch 276/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 18.2059 - mean_squared_error: 18.2059 - val_loss: 46.0169 - val_mean_squared_error: 46.0169
# Epoch 277/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 45.5599 - mean_squared_error: 45.5599 - val_loss: 131.0949 - val_mean_squared_error: 131.0949
# Epoch 278/1000
# 64/64 [==============================] - 0s 5ms/step - loss: 140.6725 - mean_squared_error: 140.6725 - val_loss: 85.6657 - val_mean_squared_error: 85.6657

# %%
predictions = nn.predict(X_test)

TestingData = X_test.copy()
TestingData["Price"] = Y_test
TestingData["PredictedPrice"] = predictions
# Out:
# 482/482 [==============================] - 1s 2ms/step

# %%
def accuracy(y_true, y_pred):
    ape = np.mean(100 * np.abs(y_true - y_pred) / y_true)
    return 100 - ape

# %%
print('The average difference is: ', accuracy(TestingData['Price'], TestingData['PredictedPrice']))
# Out:
# The average difference is:  98.1123920773752

# %%
batch_sizes = [128, 256, 512, 1024]
# epochs = [100, 200, 500, 1000]
learning_rates = [0.001, 0.003, 0.01]

best_model = None
best_accuracy = 0
best_batch_size = 0
best_epoch = 0
best_learning_rate = 0

epoch = 100

for batch_size in batch_sizes:
    # for epoch in epochs:
      for lr in learning_rates:
          nn.compile(loss='mean_squared_error',
                      optimizer=optimizers.Adam(learning_rate=lr),
                      metrics=['mean_squared_error']) 
          history = nn.fit(X_train, Y_train, epochs=epoch, batch_size=batch_size, validation_split = 0.1, callbacks=[early_stop], verbose=0)
          preds = nn.predict(X_test, verbose=0)
          TestingData = X_test.copy()
          TestingData["Price"] = Y_test
          TestingData["PredictedPrice"] = preds
          print('The average difference is: ' +  str(accuracy(TestingData['Price'], TestingData['PredictedPrice'])) + " for batch size: " + str(batch_size) + " for epoch: " + str(epoch) + " for learning rate: " + str(lr))

          if best_model is None:
              best_model = nn
              best_accuracy = accuracy(TestingData['Price'], TestingData['PredictedPrice'])
              best_batch_size = batch_size
              best_epoch = epoch
              best_learning_rate = lr
          else:
              if accuracy(TestingData['Price'], TestingData['PredictedPrice']) > best_accuracy:
                  best_model = nn
                  best_accuracy = accuracy(TestingData['Price'], TestingData['PredictedPrice'])
                  best_batch_size = batch_size
                  best_epoch = epoch
                  best_learning_rate = lr
            
print('Best model: ', best_model)
print('Best accuracy: ', best_accuracy)
print('Best batch size: ', best_batch_size)
print('Best epoch: ', best_epoch)
print('Best learning rate: ', best_learning_rate)
# Plotting the loss
# Out:
# The average difference is: 98.51738534963334 for batch size: 128 for epoch: 100 for learning rate: 0.001
# The average difference is: 98.0206157607898 for batch size: 128 for epoch: 100 for learning rate: 0.003
# The average difference is: 95.23460179007289 for batch size: 128 for epoch: 100 for learning rate: 0.01
# The average difference is: 98.4239060211439 for batch size: 256 for epoch: 100 for learning rate: 0.001
# The average difference is: 98.49162472496837 for batch size: 256 for epoch: 100 for learning rate: 0.003
# The average difference is: 97.99516696071991 for batch size: 256 for epoch: 100 for learning rate: 0.01
# The average difference is: 99.24218128320133 for batch size: 512 for epoch: 100 for learning rate: 0.001
# The average difference is: 99.20476682915529 for batch size: 512 for epoch: 100 for learning rate: 0.003
# The average difference is: 98.36239347548872 for batch size: 512 for epoch: 100 for learning rate: 0.01
# The average difference is: 99.3975551827983 for batch size: 1024 for epoch: 100 for learning rate: 0.001
# The average difference is: 99.28063201117035 for batch size: 1024 for epoch: 100 for learning rate: 0.003
# The average difference is: 99.15106218442389 for batch size: 1024 for epoch: 100 for learning rate: 0.01
# Best model:  <keras.engine.sequential.Sequential object at 0x0000015FC3031730>
# Best accuracy:  99.3975551827983
# Best batch size:  1024
# Best epoch:  100
# Best learning rate:  0.001

# %%
# Answer questions

# %%
predictions = best_model.predict(X_test)

TestingData = X_test.copy()
TestingData["Price"] = Y_test
TestingData["PredictedPrice"] = predictions
# Out:
# 482/482 [==============================] - 1s 2ms/step

# %%
overvalued = TestingData[(TestingData["Price"] - TestingData["PredictedPrice"]) / TestingData["Price"] > 0.05]
undervalued = TestingData[(TestingData["Price"] - TestingData["PredictedPrice"]) / TestingData["Price"] < -0.05]
accuratelyPriced = TestingData[abs((TestingData["Price"] - TestingData["PredictedPrice"]) / TestingData["Price"]) <= 0.05]

print("Overvalued: " + str(len(overvalued)))
print("Undervalued: " + str(len(undervalued)))
print("Accurately Priced: " + str(len(accuratelyPriced)))
print("Check sum: " + str((len(overvalued) + len(undervalued) + len(accuratelyPriced)) == len(X_test)))

overvalued["isOvervalued"] = 1
accuratelyPriced["isOvervalued"] = 0
undervalued["isOvervalued"] = 0

overvalued["isUndervalued"] = 0
accuratelyPriced["isUndervalued"] = 0
undervalued["isUndervalued"] = 1

result_df = pd.concat([overvalued, accuratelyPriced, undervalued])
# Out:
# Overvalued: 117
# Undervalued: 61
# Accurately Priced: 15226
# Check sum: True
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2916362890.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2916362890.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2916362890.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2916362890.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2916362890.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harpe\AppData\Local\Temp/ipykernel_47940/2916362890.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
X_overval = result_df.drop(["isOvervalued", "isUndervalued", "price_log", "Price", "PredictedPrice"], axis=1) 
y_overval = result_df["isOvervalued"]

clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_overval, y_overval)
# Out:
# RandomForestClassifier(random_state=42)

# %%
import pandas as pd

overval_importances = clf.feature_importances_
overval_feature_importances = pd.DataFrame({'feature': list(X_overval.columns), 'importance': importances})

# %%
import matplotlib.pyplot as plt

overval_feature_importances = overval_feature_importances.sort_values('importance', ascending=False)

plt.figure(figsize=(10, 5))
plt.bar(overval_feature_importances['feature'], overval_feature_importances['importance'])
plt.xticks(rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importance for Overvalued Listings')
plt.show()

# %%
# Undervalued

# %%
X_underval = result_df.drop(["isOvervalued", "isUndervalued", "price_log", "Price", "PredictedPrice"], axis=1) 
y_underval = result_df["isUndervalued"]

clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_underval, y_underval)
# Out:
# RandomForestClassifier(random_state=42)

# %%
underval_importances = clf.feature_importances_
underval_feature_importances = pd.DataFrame({'feature': list(X_underval.columns), 'importance': importances})

# %%
underval_feature_importances = underval_feature_importances.sort_values('importance', ascending=False)

plt.figure(figsize=(10, 5))
plt.bar(underval_feature_importances['feature'], underval_feature_importances['importance'])
plt.xticks(rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importance for Undervalued Listings')
plt.show()
